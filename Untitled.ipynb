# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
def costheta(costheta, A = 1, B = 1):
    return A*(1+costheta**2)+B*costheta

# %%
X = np.linspace(-1,1,100)
y = costheta(X,B = -1)

# %%
plt.plot(X,y)

# %%
randoms = np.random.uniform(-1,1, size=10000)

# %%
samples = []
nsamples = 10000
ymax = np.max(y)
while True:
    x = np.random.uniform(-1,1)
    cut = np.random.uniform(0,ymax)
    if costheta(x,A = 1, B = 1) < cut:
        samples.append(x)
    if not len(samples) < nsamples:
        break
samples = np.array(samples)
print len(samples)
# Out:
# 10000

# %%
plt.hist(samples)
# Out:
# (array([ 1276.,  1309.,  1341.,  1295.,  1227.,  1137.,   980.,   743.,
#           493.,   199.]),
#  array([-0.99982923, -0.80069798, -0.60156674, -0.4024355 , -0.20330426,
#         -0.00417301,  0.19495823,  0.39408947,  0.59322072,  0.79235196,
#          0.9914832 ]),
#  <a list of 10 Patch objects>)
